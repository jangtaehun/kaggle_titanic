# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

pd.set_option('display.max_columns', None)

train_df = pd.read_csv('./titanic/data/titanic_train.csv')
predict_df = pd.read_csv('./titanic/data/test.csv')
gender_submission_df = pd.read_csv('./titanic/gender_submission.csv')

# %%
print("train_df 데이터의 행 개수:", len(train_df))
print('train_df: 데이터 세트 Null 값 갯수 ',train_df.isnull().sum().sum())
print(train_df.isnull().sum())
print(train_df.columns)
print("------------------------------------------------------------ \n\n")

print("predict_df 데이터의 행 개수:", len(predict_df))
print('predict_df: 데이터 세트 Null 값 갯수 ',predict_df.isnull().sum().sum())
print(predict_df.isnull().sum())
print(predict_df.columns)
print("------------------------------------------------------------ \n\n")

print(f"gender_submission_df 데이터의 행 개수: {gender_submission_df.shape[0]}")
print('gender_submission_df: 데이터 세트 Null 값 갯수 ',gender_submission_df.isnull().sum().sum())
print(gender_submission_df.isnull().sum())
# Out:
# train_df 데이터의 행 개수: 891
# train_df: 데이터 세트 Null 값 갯수  2232
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# WikiId           2
# Name_wiki        2
# Age_wiki         4
# Hometown         2
# Boarded          2
# Destination      2
# Lifeboat       546
# Body           804
# Class            2
# dtype: int64
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked', 'WikiId', 'Name_wiki',
#        'Age_wiki', 'Hometown', 'Boarded', 'Destination', 'Lifeboat', 'Body',
#        'Class'],
#       dtype='object')
# ------------------------------------------------------------
#
#
# predict_df 데이터의 행 개수: 418
# predict_df: 데이터 세트 Null 값 갯수  1071
# PassengerId      0
# Pclass           0
# Name             0
# Sex              0
# Age             86
# SibSp            0
# Parch            0
# Ticket           0
# Fare             1
# Cabin          327
# Embarked         0
# WikiId           3
# Name_wiki        3
# Age_wiki         3
# Hometown         3
# Boarded          3
# Destination      3
# Lifeboat       261
# Body           375
# Class            3
# dtype: int64
# Index(['PassengerId', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp', 'Parch',
#        'Ticket', 'Fare', 'Cabin', 'Embarked', 'WikiId', 'Name_wiki',
#        'Age_wiki', 'Hometown', 'Boarded', 'Destination', 'Lifeboat', 'Body',
#        'Class'],
#       dtype='object')
# ------------------------------------------------------------
#
#
# gender_submission_df 데이터의 행 개수: 418
# gender_submission_df: 데이터 세트 Null 값 갯수  0
# PassengerId    0
# Survived       0
# dtype: int64

# %%
train_df.drop(['PassengerId','Name', 'Ticket', 'Cabin', 'WikiId', 'Hometown', 'Boarded', 'Destination', 'Lifeboat', 'Body', 'Class'], axis=1, inplace=True)
train_df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1       0.0       3
# 1              2       1.0       1
# 2              3       1.0       3
# 3              4       1.0       1
# 4              5       0.0       3
# ..           ...       ...     ...
# 886          887       0.0       2
# 887          888       1.0       1
# 888          889       0.0       3
# 889          890       1.0       1
# 890          891       0.0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# 886                              Montvila, Rev. Juozas    male  27.0      0
# 887                       Graham, Miss. Margaret Edith  female  19.0      0
# 888           Johnston, Miss. Catherine Helen "Carrie"  female   NaN      1
# 889                              Behr, Mr. Karl Howell    male  26.0      0
# 890                                Dooley, Mr. Patrick    male  32.0      0
#
#      Parch            Ticket     Fare Cabin Embarked  WikiId  \
# 0        0         A/5 21171   7.2500   NaN        S   691.0
# 1        0          PC 17599  71.2833   C85        C    90.0
# 2        0  STON/O2. 3101282   7.9250   NaN        S   865.0
# 3        0            113803  53.1000  C123        S   127.0
# 4        0            373450   8.0500   NaN        S   627.0
# ..     ...               ...      ...   ...      ...     ...
# 886      0            211536  13.0000   NaN        S   514.0
# 887      0            112053  30.0000   B42        S   137.0
# 888      2        W./C. 6607  23.4500   NaN        S   910.0
# 889      0            111369  30.0000  C148        C    28.0
# 890      0            370376   7.7500   NaN        Q   783.0
#
#                                       Name_wiki  Age_wiki  \
# 0                       Braund, Mr. Owen Harris      22.0
# 1    Cumings, Mrs. Florence Briggs (née Thayer)      35.0
# 2                         Heikkinen, Miss Laina      26.0
# 3            Futrelle, Mrs. Lily May (née Peel)      35.0
# 4                      Allen, Mr. William Henry      35.0
# ..                                          ...       ...
# 886                     Montvila, Father Juozas      27.0
# 887                 Graham, Miss Margaret Edith      19.0
# 888             Johnston, Miss Catherine Nellie       7.0
# 889                       Behr, Mr. Karl Howell      26.0
# 890                      Dooley, Mr. Patrick J.      43.0
#
#                                Hometown      Boarded  \
# 0            Bridgerule, Devon, England  Southampton
# 1                New York, New York, US    Cherbourg
# 2                    Jyväskylä, Finland  Southampton
# 3           Scituate, Massachusetts, US  Southampton
# 4    Birmingham, West Midlands, England  Southampton
# ..                                  ...          ...
# 886              Gudinė, Lithuania [76]  Southampton
# 887          Greenwich, Connecticut, US  Southampton
# 888     Thornton Heath, London, England  Southampton
# 889              New York, New York, US    Cherbourg
# 890     Patrickswell, Limerick, Ireland   Queenstown
#
#                                  Destination Lifeboat Body  Class
# 0    Qu'Appelle Valley, Saskatchewan, Canada      NaN  NaN    3.0
# 1                     New York, New York, US        4  NaN    1.0
# 2                              New York City      14?  NaN    3.0
# 3                Scituate, Massachusetts, US        D  NaN    1.0
# 4                              New York City      NaN  NaN    3.0
# ..                                       ...      ...  ...    ...
# 886             Worcester, Massachusetts, US      NaN  NaN    2.0
# 887               Greenwich, Connecticut, US        3  NaN    1.0
# 888              New London, Connecticut, US      NaN  NaN    3.0
# 889                   New York, New York, US        5  NaN    1.0
# 890                            New York City      NaN  NaN    3.0
#
# [891 rows x 21 columns]
